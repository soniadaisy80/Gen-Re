# %%
import matplotlib.pyplot as plt

# Data for real GDP growth rate (year-on-year %) from 2012 to 2022
years = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
oil_and_gas_growth = [21.6, 18.0, 9.3, 2.0, -15.6, 80.3, 8.0, 14.4, -4.6, -12.6, -8.5]
transport_storage_growth = [9.2, -0.5, 5.8, 2.6, 1.1, 9.0, 1.1, 4.3, 4.1, 7.2, 4.0]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(years, oil_and_gas_growth, marker='o', label='Oil and Gas')
plt.plot(years, transport_storage_growth, marker='s', label='Transport and Storage')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Real GDP Growth Rate (Year-on-Year %)')
plt.title('Real GDP Growth Rate (2012–2022): Oil and Gas vs Transport and Storage')
plt.legend()
plt.grid(True)
plt.xticks(years)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
co2_total_excl_lulucf = [14.6402,15.5631,14.9977, 15.7885, 16.1935, 16.9641, 19.1324, 
                         20.2014, 22.149, 25.0095,24.7887]  # Replace 36.00000 with actual 2022 value if available

# Plot
plt.figure(figsize=(10, 6))
plt.plot(years, co2_total_excl_lulucf, marker='o', color='blue')
plt.title('CO₂ Emissions Total Excluding LULUCF (2012–2022)')
plt.xlabel('Year')
plt.ylabel('CO₂ Emissions (Mt CO₂e)')
plt.grid(True)
plt.xticks(years)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
co2_per_capita = [0.547619257800513, 0.568282710926634, 0.53483767968666, 0.55019733017081, 0.551610938298262,
                  0.56531257929042, 0.624474807658632, 0.646259814590671, 0.694591465973721, 0.769081387566187, 0.74779288471693]  # Replace 5.95000 with actual 2022 value if available

# Plot
plt.figure(figsize=(10, 6))
plt.plot(years, co2_per_capita, marker='s', color='green')
plt.title('CO₂ Emissions per Capita Excluding LULUCF (2012–2022)')
plt.xlabel('Year')
plt.ylabel('CO₂ Emissions per Capita (t CO₂e/capita)')
plt.grid(True)
plt.xticks(years)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the spreadsheet
years = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
inflation_rates = [11.1863409441067, 11.6661923071729, 15.4896160333318,
                   17.1499695007878, 17.4546347070868, 12.3719215507048, 
                   7.80876516610703, 7.14364003330857,  9.88728956269944, 9.9710886750444, 
                   31.2558951049016 ]  # Replace 10.0 with actual 2022 value if available

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(years, inflation_rates, marker='o', linestyle='-', color='Purple')

# Add titles and labels
plt.title('Inflation, Consumer Prices (Annual %)')
plt.xlabel('Year')
plt.ylabel('Inflation Rate (%)')
plt.grid(True)
plt.xticks(years)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for GDP growth (annual %)
years = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
gdp_growth = [9.2927894063005, 7.31252501678145,2.85624016330883, 2.12075933817334, 3.37346574966936, 8.12889488100956,
               6.20007768127284, 6.5077747939152, 0.513941670628171, 5.07646643533542, 3.80484980952164]

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(years, gdp_growth, marker='o', linestyle='-', color='Brown')

# Add title and labels
plt.title('GDP Growth (Annual %) from 2012 to 2022')
plt.xlabel('Year')
plt.ylabel('GDP Growth (%)')
plt.grid(True)
plt.xticks(years)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2012, 2013, 2014, 2015, 2016, 2017, 
         2018, 2019, 2020, 2021, 2022]
current_account_balance = [-8.8, -9.1, -6.8, -5.7, -5.1,
                           -3.3, -3.0, -2.2, -2.5, -2.7, -2.3]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, current_account_balance, marker='o', linestyle='-', color='orange')
plt.title('Current Account Balance (% of GDP), 2012–2022')
plt.xlabel('Year')
plt.ylabel('Percent of GDP')
plt.grid(True)
plt.xticks(years)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2012, 2013, 2014, 2015, 2016, 2017, 
         2018, 2019, 2020, 2021, 2022]
debt_percent_gdp = [35.5, 42.9, 50.1, 53.9, 55.9, 
                    57.0, 62.0, 58.3, 72.3, 79.2, 85.7]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, debt_percent_gdp, marker='o', linestyle='-', color='Brown')
plt.title('General Government Gross Debt (% of GDP), 2012–2022')
plt.xlabel('Year')
plt.ylabel('Percent of GDP')
plt.grid(True)
plt.xticks(years)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2012, 2013, 2014, 2015, 2016, 2017, 
         2018, 2019, 2020, 2021, 2022]
net_lending_borrowing = [-8.4, -9.1, -7.8, -4.0, -6.7, 
                         -4.0, -6.8, -7.5, -17.4, -12.0, 11.8]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, net_lending_borrowing, marker='o', linestyle='-', color='indigo')
plt.title('General Government Net Lending/Borrowing (% of GDP), 2012–2022')
plt.xlabel('Year')
plt.ylabel('Percent of GDP')
plt.grid(True)
plt.xticks(years)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2012, 2013, 2014, 2015, 2016, 2017, 
         2018, 2019, 2020, 2021, 2022]
ppp_conversion_rate = [0.886, 0.994, 1.211, 1.358, 1.558, 1.694, 
                       1.819, 1.900, 2.033, 2.149, 2.571,]  # Assuming 2022 is 2.650 if missing

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, ppp_conversion_rate, marker='o', linestyle='-', color='red')
plt.title('Implied PPP Conversion Rate (National currency per international dollar), 2012–2022')
plt.xlabel('Year')
plt.ylabel('PPP Conversion Rate')
plt.grid(True)
plt.xticks(years)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2012, 2013, 2014, 2015, 2016, 2017, 
         2018, 2019, 2020, 2021, 2022]
inflation_rates = [7.1, 11.7, 15.5, 17.2, 17.5, 
                   12.4, 9.8, 7.2, 9.9, 10.0, 31.9]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, inflation_rates, marker='o', linestyle='-', color='green')
plt.title('Inflation Rate, Average Consumer Prices (Annual Percent Change), 2012–2022')
plt.xlabel('Year')
plt.ylabel('Inflation Rate (%)')
plt.grid(True)
plt.xticks(years)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2012, 2013, 2014, 2015, 2016, 2017, 
         2018, 2019, 2020, 2021, 2022]
inflation_end_period = [8.1, 13.5, 17.0, 17.7, 15.4, 
                        11.8, 9.4, 7.9, 10.5, 12.6, 54.1]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, inflation_end_period, marker='o', linestyle='-', color='Brown')
plt.title('Inflation Rate, End of Period Consumer Prices (Annual % Change), 2012–2022')
plt.xlabel('Year')
plt.ylabel('Inflation Rate (%)')
plt.grid(True)
plt.xticks(years)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
real_gdp_growth = [8.4, 7.2, 2.9, 2.1, 3.4, 8.1, 6.2, 6.5, 0.5, 5.1, 3.8]

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(years, real_gdp_growth, color='skyblue')
plt.title('Real GDP Growth (Annual Percent Change), 2012–2022')
plt.xlabel('Year')
plt.ylabel('Growth Rate (%)')
plt.xticks(years)
plt.grid(axis='y')
plt.tight_layout()

# %%
import matplotlib.pyplot as plt

# Data extracted from the image
years = [2012, 2013, 2014, 2015, 2016, 2017, 
         2018, 2019, 2020, 2021, 2022]
population_millions = [26.734, 27.386, 28.042, 28.696, 29.357, 
                       30.008, 30.638, 31.259, 31.888, 32.519, 33.149]

# Plotting the line chart
plt.figure(figsize=(10, 6))
plt.plot(years, population_millions, marker='o', linestyle='-', color='blue')
plt.title('Population Growth (Millions of People), 2012–2022')
plt.xlabel('Year')
plt.ylabel('Population (Millions)')
plt.grid(True)
plt.xticks(years)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
fuel_types = ['LPG', 'Bio Gas', 'Electricity', 'Kerosene', 'Charcoal']
households = [3086302, 991, 32477, 112279, 1942764]

# Plotting
plt.figure(figsize=(10, 6))
bars = plt.bar(fuel_types, households, color='purple')

# Add value labels on top of bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 50000, f'{yval:,}', ha='center', va='bottom', fontsize=10)

plt.title('Number of Households in Ghana by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Number of Households')
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. LPG is the most widely used fuel among households (3M+) followed by charcoal (1.9M+) indicating a mix of modern and traditional energy sources.
# 2. Electricity and biogas usage are minimal, suggesting limited access or affordability issues.
#
# Implication: The reliance on charcoal and kerosene can have environmental and health impacts. Transitioning households to cleaner fuels like LPG or electricity could improve public health and reduce deforestation, but may require subsidies or infrastructure investment

# %%
import matplotlib.pyplot as plt

# Fuel types and their corresponding total consumption values (Metric Tonnes)
fuel_types = [
    'Premium gasoline (petrol)',
    'Gas oil (diesel)',
    'Liquefied petroleum gas',
    'Gas oil (mining & oil rigs)',
    'Aviation turbine kerosine',
    'Fuel oil (industry & power plants)',
    'Marine gasoil (local vessels)',
    'Marine gasoil (foreign vessels)',
    'Premix fuel',
    'Kerosene'
]

consumption_totals = [
    13913793.28,  # Premium gasoline
    16401560.2,   # Gas oil (diesel)
    3398646.67,   # LPG
    3341945.41,   # Gas oil by mining firms and oil rigs
    1770248.69,   # Aviation turbine kerosine
    913710.64,    # Fuel oil (industry and power plants)
    438333,       # Marine gasoil by local vessels
    270751.9,     # Marine gasoil by foreign vessels
    640436.48,    # Premix fuel
    125576.77     # Kerosene
]

# Plotting the bar chart
plt.figure(figsize=(12, 7))
bars = plt.bar(fuel_types, consumption_totals, color='gold')

# Adding value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 100000, f'{height:,.0f}', ha='center', va='bottom', fontsize=10)

# Chart labels and title
plt.title('Total Fuel Consumption in Ghana (2012–2022)', fontsize=14)
plt.xlabel('Fuel Type', fontsize=12)
plt.ylabel('Total Consumption (Metric Tonnes)', fontsize=12)
plt.grid(False)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. High consumption of diesel and pertol (16.4M and 13.9 metric tonnes respectively) suggests strong demand in transportation and industrial sectors
# 2. Diesel and petrol are critical inputs for logistics, public transport and private mobility. Their high usage reflects economic activity but also exposes the economy to global oil price volatility
# 3. Mining and oil rigs also consume significant fuel, indicating the importance of extractive industries in Ghana's economy.
#
# Implication: Rising fuel consumption can signal economic growth but it also increases vulnerability to external shocks which can drive up inflation and CPI

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the data
data = {
    'Year': [2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012],
    'Jan': [14.5, 14.5, 16.0, 16.0, 20.0, 25.5, 26.0, 21.0, 16.0, 15.0, 12.5],
    'Feb': [14.5, 14.5, 16.0, 16.0, 20.0, 25.5, 26.0, 21.0, 18.0, 15.0, 13.5],
    'Mar': [17.0, 14.5, 14.5, 16.0, 18.0, 23.5, 26.0, 21.0, 18.0, 15.0, 13.5],
    'Apr': [17.0, 14.5, 14.5, 16.0, 18.0, 23.5, 26.0, 21.0, 18.0, 15.0, 14.5],
    'May': [19.0, 13.5, 14.5, 16.0, 17.0, 22.5, 26.0, 22.0, 18.0, 16.0, 14.5],
    'Jun': [19.0, 13.5, 14.5, 16.0, 17.0, 22.5, 26.0, 22.0, 18.0, 16.0, 15.0],
    'Jul': [19.0, 13.5, 14.5, 16.0, 17.0, 21.0, 26.0, 22.0, 19.0, 16.0, 15.0],
    'Aug': [22.0, 13.5, 14.5, 16.0, 17.0, 21.0, 26.0, 24.0, 19.0, 16.0, 15.0],
    'Sep': [22.0, 13.5, 14.5, 16.0, 17.0, 21.0, 26.0, 25.0, 19.0, 16.0, 15.0],
    'Oct': [24.5, 13.5, 14.5, 16.0, 17.0, 21.0, 26.0, 25.0, 19.0, 16.0, 15.0],
    'Nov': [27.0, 14.5, 14.5, 16.0, 17.0, 20.0, 25.5, 26.0, 21.0, 16.0, 15.0],
    'Dec': [27.0, 14.5, 14.5, 16.0, 17.0, 20.0, 25.5, 26.0, 21.0, 16.0, 15.0]
}

# Create DataFrame
df = pd.DataFrame(data)

# Set 'Year' as index
df.set_index('Year', inplace=True)

# Calculate average rate for each year
df['Average Rate'] = df.mean(axis=1)

# Plot the average rates
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Average Rate'], marker='o', linestyle='-', color='blue')
plt.title('Average Monetary Policy Rate (Jan–Dec) from 2012 to 2022')
plt.xlabel('Year')
plt.ylabel('Average Rate (%)')
plt.grid(True)
plt.xticks(df.index)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data based on the image
data = {
    'Year': [2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012],
    'Jan': [20.16, 20.97, 23.06, 23.73, 25.64, 27.65, 28.81, 28.98, 25.56, 25.72, 25.93],
    'Feb': [20.52, 21.02, 23.37, 23.50, 25.38, 27.57, 28.02, 28.98, 25.56, 25.72, 25.93],
    'Mar': [20.57, 20.96, 23.40, 23.26, 25.47, 27.72, 27.97, 28.98, 25.56, 27.13, 25.93],
    'Apr': [21.61, 20.93, 22.38, 23.09, 25.02, 27.52, 27.98, 28.98, 26.98, 27.13, 25.93],
    'May': [22.53, 20.85, 22.11, 23.08, 24.74, 27.29, 28.22, 28.98, 27.85, 27.13, 25.93],
    'Jun': [24.27, 20.61, 21.95, 23.11, 24.14, 27.28, 27.90, 28.98, 27.85, 27.41, 24.65],
    'Jul': [26.46, 20.67, 21.29, 24.10, 23.94, 27.22, 28.51, 27.87, 27.75, 27.41, 24.65],
    'Aug': [27.96, 20.51, 21.37, 23.96, 23.70, 27.17, 28.15, 27.87, 27.75, 27.41, 24.51],
    'Sep': [29.81, 20.23, 21.30, 23.68, 24.04, 26.73, 27.82, 28.98, 27.45, 27.41, 25.72],
    'Oct': [31.40, 20.34, 21.26, 23.65, 23.90, 26.71, 27.96, 28.16, 26.43, 25.56, 25.72],
    'Nov': [33.87, 20.17, 20.95, 23.53, 23.76, 26.42, 28.21, 29.22, 26.43, 25.56, 25.72],
    'Dec': [35.58, 20.04, 21.10, 23.59, 23.96, 26.22, 28.09, 27.50, 28.98, 25.56, 25.72]
}

# Create DataFrame
df = pd.DataFrame(data)

# Set Year as index
df.set_index('Year', inplace=True)

df['Average Rate'] = df.mean(axis=1)

# Plotting the data
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Average Rate'], marker='o', linestyle='-', color='Red')
plt.title('Average Commercial Banks Lending Rates (2012–2022)')
plt.xlabel('Year')
plt.ylabel('Lending Rate (%)')
plt.grid(True)
plt.xticks(df.index)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data based on the image
data = {
    'Year': [2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012],
    'GHS/USD': [-30.0, -4.1, -3.9, -12.9, -8.4, -4.9, -9.7, -15.7, -31.3, -14.5, -17.5],
    'GHS/GBP': [-21.2, -3.1, -7.1, 15.7, -3.3, -12.9, 8.3, -11.5, -26.3, -16.7, 18.4],
    'GHS/EURO': [-25.3, 3.5, -12.1, -11.2, -3.9, -16.2, -6.4, -6.2, -20.5, -20.1, -14.9]
}

# Create DataFrame
df = pd.DataFrame(data)

# Set Year as index
df.set_index('Year', inplace=True)

# Bar width and positions
bar_width = 0.25
x = range(len(df.index))  # Corrected: generate x positions based on number of years

# Plotting
plt.figure(figsize=(12, 6))
plt.bar([i - bar_width for i in x], df['GHS/USD'], width=bar_width, label='GHS/USD')
plt.bar(x, df['GHS/GBP'], width=bar_width, label='GHS/GBP')
plt.bar([i + bar_width for i in x], df['GHS/EURO'], width=bar_width, label='GHS/EURO')

# Labels and title
plt.xticks(ticks=x, labels=df.index, rotation=0)
plt.xlabel('Year')
plt.ylabel('Exchange Rate Y-o-Y (%)')
plt.title('Inter-Bank Exchange Rate Year-on-Year Change (2012–2022)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the Excel sheet
categories = ['Month-on-month inflation (%)', 'Consumer Price Index', 'Year-on-year inflation (%)']
values = [1.809848485, 66.63500606, 21.17422424]
colors = ['blue', 'orange', 'gray']

# Create a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, values, color=colors)

# Add titles and labels
plt.title('Average Consumer Price Index and Inflation for Transport 2012-2022')
plt.xlabel('Indicators')
plt.ylabel('Values')

# Add value labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval:.2f}', ha='center', va='bottom')

# Add legend
for i in range(len(categories)):
    plt.bar(0, 0, color=colors[i], label=categories[i])  # Dummy bars for legend

plt.legend(title='Indicators')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. The year-on-year inflation rate for transport is high at 21.17% with a CPI of 66.64, indication that transportation costs have significantly increased over the years.
# 2. Month-on-month inflation is relatively moderate at 1.81% suggesting recent price stability or slower growth
#
# Implication: Fuel prices are a major driver of transport inflation. As fuel costs rise, transportation becomes more expensive which can cascade into higher prices for goods and services contributing to overall inflation

# %%
import matplotlib.pyplot as plt

# Data from the Excel sheet
categories = ['Month-on-month inflation (%)', 'Consumer Price Index', 'Year-on-year inflation (%)']
values = [1.791666667, 63.84924242, 21.61363636]
colors = ['blue', 'orange', 'gray']

# Create a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, values, color=colors)

# Add titles and labels
plt.title('AVG Consumer Price Index and Inflation for Housing, water, electricity, gas and other fuels 2012-2022')
plt.xlabel('Indicators')
plt.ylabel('Values')

# Add value labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval:.2f}', ha='center', va='bottom')

# Add legend
for i in range(len(categories)):
    plt.bar(0, 0, color=colors[i], label=categories[i])  # Dummy bars for legend

plt.legend(title='Indicators')

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the Excel sheet
categories = ['Month-on-month inflation (%)', 'Consumer Price Index', 'Year-on-year inflation (%)']
values = [1.002272727, 76.69469697, 10.21212121]
colors = ['blue', 'orange', 'gray']

# Create a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, values, color=colors)

# Add titles and labels
plt.title('Avergae Consumer Price Index and Inflation for Food 2012-2022')
plt.xlabel('Indicators')
plt.ylabel('Values')

# Add value labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval:.2f}', ha='center', va='bottom')

# Add legend
for i in range(len(categories)):
    plt.bar(0, 0, color=colors[i], label=categories[i])  # Dummy bars for legend

plt.legend(title='Indicators')

# Show plot
plt.tight_layout()
plt.show()
